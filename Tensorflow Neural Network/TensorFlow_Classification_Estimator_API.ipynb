# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure  ...  Age  Class  Group
# 0                6               0.743719        0.590164  ...   50      1      B
# 1                1               0.427136        0.540984  ...   31      0      C
# 2                8               0.919598        0.524590  ...   32      1      B
# 3                1               0.447236        0.540984  ...   21      0      B
# 4                0               0.688442        0.327869  ...   33      1      C
#
# [5 rows x 10 columns]

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure  ...  Age  Class  Group
# 0         0.352941               0.743719        0.590164  ...   50      1      B
# 1         0.058824               0.427136        0.540984  ...   31      0      C
# 2         0.470588               0.919598        0.524590  ...   32      1      B
# 3         0.058824               0.447236        0.540984  ...   21      0      B
# 4         0.000000               0.688442        0.327869  ...   33      1      C
#
# [5 rows x 10 columns]

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure  ...  Age  Class  Group
# 0         0.352941               0.743719        0.590164  ...   50      1      B
# 1         0.058824               0.427136        0.540984  ...   31      0      C
# 2         0.470588               0.919598        0.524590  ...   32      1      B
# 3         0.058824               0.447236        0.540984  ...   21      0      B
# 4         0.000000               0.688442        0.327869  ...   33      1      C
#
# [5 rows x 10 columns]

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpi9lu842n
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpi9lu842n', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5ef1d92710>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/feature_column/feature_column_v2.py:305: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/embedding_ops.py:802: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/canned/linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/training/monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpi9lu842n/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 276.029
# INFO:tensorflow:loss = 6.180522, step = 101 (0.370 sec)
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 105 vs previous value: 105. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 128 vs previous value: 128. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 130 vs previous value: 130. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 143 vs previous value: 143. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 149 vs previous value: 149. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:global_step/sec: 370.391
# INFO:tensorflow:loss = 6.7122164, step = 201 (0.268 sec)
# INFO:tensorflow:global_step/sec: 419.019
# INFO:tensorflow:loss = 7.431712, step = 301 (0.241 sec)
# INFO:tensorflow:global_step/sec: 375.477
# INFO:tensorflow:loss = 5.7528, step = 401 (0.264 sec)
# INFO:tensorflow:global_step/sec: 456.222
# INFO:tensorflow:loss = 5.823148, step = 501 (0.217 sec)
# INFO:tensorflow:global_step/sec: 386.796
# INFO:tensorflow:loss = 3.3155518, step = 601 (0.260 sec)
# INFO:tensorflow:global_step/sec: 390.039
# INFO:tensorflow:loss = 5.506713, step = 701 (0.255 sec)
# INFO:tensorflow:global_step/sec: 398.863
# INFO:tensorflow:loss = 6.08858, step = 801 (0.251 sec)
# INFO:tensorflow:global_step/sec: 409.083
# INFO:tensorflow:loss = 2.3643467, step = 901 (0.245 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpi9lu842n/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.6673527.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/metrics_impl.py:2026: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-03-17T21:09:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpi9lu842n/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-03-17-21:09:57
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72440946, accuracy_baseline = 0.65748036, auc = 0.7865304, auc_precision_recall = 0.62628067, average_loss = 0.531644, global_step = 1000, label/mean = 0.34251967, loss = 5.193753, precision = 0.6075949, prediction/mean = 0.3679907, recall = 0.55172414
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmpi9lu842n/model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7865304,
#  'auc_precision_recall': 0.62628067,
#  'average_loss': 0.531644,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.193753,
#  'precision': 0.6075949,
#  'prediction/mean': 0.3679907,
#  'recall': 0.55172414}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpi9lu842n/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53560865], dtype=float32),
#   'logits': array([0.14267612], dtype=float32),
#   'probabilities': array([0.46439138, 0.53560865], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63465184], dtype=float32),
#   'logits': array([0.55222595], dtype=float32),
#   'probabilities': array([0.36534813, 0.6346519 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3813161], dtype=float32),
#   'logits': array([-0.48396587], dtype=float32),
#   'probabilities': array([0.61868393, 0.3813161 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31302088], dtype=float32),
#   'logits': array([-0.7860341], dtype=float32),
#   'probabilities': array([0.6869791 , 0.31302086], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13887277], dtype=float32),
#   'logits': array([-1.8246841], dtype=float32),
#   'probabilities': array([0.8611272 , 0.13887276], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.70234096], dtype=float32),
#   'logits': array([0.85847044], dtype=float32),
#   'probabilities': array([0.29765904, 0.702341  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60050136], dtype=float32),
#   'logits': array([0.40755463], dtype=float32),
#   'probabilities': array([0.3994986 , 0.60050136], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35439584], dtype=float32),
#   'logits': array([-0.59977216], dtype=float32),
#   'probabilities': array([0.6456042 , 0.35439584], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23278974], dtype=float32),
#   'logits': array([-1.1926253], dtype=float32),
#   'probabilities': array([0.76721025, 0.23278973], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25162476], dtype=float32),
#   'logits': array([-1.0899656], dtype=float32),
#   'probabilities': array([0.7483752 , 0.25162473], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12831652], dtype=float32),
#   'logits': array([-1.9159263], dtype=float32),
#   'probabilities': array([0.87168354, 0.12831654], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14670372], dtype=float32),
#   'logits': array([-1.7606918], dtype=float32),
#   'probabilities': array([0.8532963 , 0.14670372], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29093647], dtype=float32),
#   'logits': array([-0.8908403], dtype=float32),
#   'probabilities': array([0.70906353, 0.29093644], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58471334], dtype=float32),
#   'logits': array([0.3421526], dtype=float32),
#   'probabilities': array([0.41528666, 0.58471334], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16986138], dtype=float32),
#   'logits': array([-1.5866101], dtype=float32),
#   'probabilities': array([0.8301386 , 0.16986138], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3139212], dtype=float32),
#   'logits': array([-0.78185046], dtype=float32),
#   'probabilities': array([0.6860788, 0.3139212], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35314208], dtype=float32),
#   'logits': array([-0.6052563], dtype=float32),
#   'probabilities': array([0.646858  , 0.35314208], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12709773], dtype=float32),
#   'logits': array([-1.926867], dtype=float32),
#   'probabilities': array([0.8729022 , 0.12709776], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35573444], dtype=float32),
#   'logits': array([-0.59392655], dtype=float32),
#   'probabilities': array([0.64426553, 0.3557344 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13372207], dtype=float32),
#   'logits': array([-1.8684423], dtype=float32),
#   'probabilities': array([0.866278  , 0.13372208], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20693374], dtype=float32),
#   'logits': array([-1.3435082], dtype=float32),
#   'probabilities': array([0.7930663 , 0.20693374], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29198384], dtype=float32),
#   'logits': array([-0.88576853], dtype=float32),
#   'probabilities': array([0.70801616, 0.2919838 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66659427], dtype=float32),
#   'logits': array([0.6928214], dtype=float32),
#   'probabilities': array([0.33340576, 0.6665943 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20745546], dtype=float32),
#   'logits': array([-1.3403319], dtype=float32),
#   'probabilities': array([0.7925445 , 0.20745547], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16594255], dtype=float32),
#   'logits': array([-1.6146605], dtype=float32),
#   'probabilities': array([0.83405745, 0.16594256], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7615547], dtype=float32),
#   'logits': array([1.161222], dtype=float32),
#   'probabilities': array([0.23844533, 0.7615547 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17499322], dtype=float32),
#   'logits': array([-1.5506443], dtype=float32),
#   'probabilities': array([0.8250068 , 0.17499323], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3135184], dtype=float32),
#   'logits': array([-0.78372145], dtype=float32),
#   'probabilities': array([0.68648165, 0.3135184 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10040897], dtype=float32),
#   'logits': array([-2.1926887], dtype=float32),
#   'probabilities': array([0.899591  , 0.10040896], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59570116], dtype=float32),
#   'logits': array([0.3875847], dtype=float32),
#   'probabilities': array([0.40429887, 0.59570116], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.94252825], dtype=float32),
#   'logits': array([2.7972724], dtype=float32),
#   'probabilities': array([0.05747174, 0.94252825], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.410959], dtype=float32),
#   'logits': array([-0.36000228], dtype=float32),
#   'probabilities': array([0.589041  , 0.41095904], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30376226], dtype=float32),
#   'logits': array([-0.82944596], dtype=float32),
#   'probabilities': array([0.69623774, 0.30376223], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5720702], dtype=float32),
#   'logits': array([0.2903024], dtype=float32),
#   'probabilities': array([0.42792985, 0.5720702 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22821808], dtype=float32),
#   'logits': array([-1.2184004], dtype=float32),
#   'probabilities': array([0.7717819, 0.2282181], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37536842], dtype=float32),
#   'logits': array([-0.50925404], dtype=float32),
#   'probabilities': array([0.6246316 , 0.37536842], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5210678], dtype=float32),
#   'logits': array([0.08432102], dtype=float32),
#   'probabilities': array([0.47893226, 0.5210678 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64263004], dtype=float32),
#   'logits': array([0.5867977], dtype=float32),
#   'probabilities': array([0.35736993, 0.64263004], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76377094], dtype=float32),
#   'logits': array([1.173466], dtype=float32),
#   'probabilities': array([0.23622908, 0.76377094], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3306297], dtype=float32),
#   'logits': array([-0.7053384], dtype=float32),
#   'probabilities': array([0.6693703, 0.3306297], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17572111], dtype=float32),
#   'logits': array([-1.5456107], dtype=float32),
#   'probabilities': array([0.8242789 , 0.17572112], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.546632], dtype=float32),
#   'logits': array([0.18707168], dtype=float32),
#   'probabilities': array([0.45336798, 0.546632  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.140311], dtype=float32),
#   'logits': array([-1.8127093], dtype=float32),
#   'probabilities': array([0.859689, 0.140311], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5317101], dtype=float32),
#   'logits': array([0.12701094], dtype=float32),
#   'probabilities': array([0.46828988, 0.53171015], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12884694], dtype=float32),
#   'logits': array([-1.9111923], dtype=float32),
#   'probabilities': array([0.87115306, 0.12884696], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10125297], dtype=float32),
#   'logits': array([-2.1833792], dtype=float32),
#   'probabilities': array([0.898747  , 0.10125301], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6120739], dtype=float32),
#   'logits': array([0.45603824], dtype=float32),
#   'probabilities': array([0.3879261 , 0.61207396], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17882434], dtype=float32),
#   'logits': array([-1.5243329], dtype=float32),
#   'probabilities': array([0.82117563, 0.17882437], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18965338], dtype=float32),
#   'logits': array([-1.452264], dtype=float32),
#   'probabilities': array([0.81034666, 0.1896534 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11529082], dtype=float32),
#   'logits': array([-2.0378013], dtype=float32),
#   'probabilities': array([0.8847092 , 0.11529081], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16276526], dtype=float32),
#   'logits': array([-1.6377957], dtype=float32),
#   'probabilities': array([0.8372348 , 0.16276523], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25159103], dtype=float32),
#   'logits': array([-1.090145], dtype=float32),
#   'probabilities': array([0.748409  , 0.25159097], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24283051], dtype=float32),
#   'logits': array([-1.1372235], dtype=float32),
#   'probabilities': array([0.7571695, 0.2428305], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38012108], dtype=float32),
#   'logits': array([-0.48903435], dtype=float32),
#   'probabilities': array([0.6198789 , 0.38012105], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12145057], dtype=float32),
#   'logits': array([-1.9787644], dtype=float32),
#   'probabilities': array([0.87854934, 0.1214506 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21172082], dtype=float32),
#   'logits': array([-1.3145835], dtype=float32),
#   'probabilities': array([0.7882791 , 0.21172085], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20446444], dtype=float32),
#   'logits': array([-1.3586216], dtype=float32),
#   'probabilities': array([0.7955356 , 0.20446444], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.204981], dtype=float32),
#   'logits': array([-1.355449], dtype=float32),
#   'probabilities': array([0.795019  , 0.20498094], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4855413], dtype=float32),
#   'logits': array([-0.05785084], dtype=float32),
#   'probabilities': array([0.5144587 , 0.48554137], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15465848], dtype=float32),
#   'logits': array([-1.6985214], dtype=float32),
#   'probabilities': array([0.8453415 , 0.15465848], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22154355], dtype=float32),
#   'logits': array([-1.2566938], dtype=float32),
#   'probabilities': array([0.77845645, 0.22154355], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6589062], dtype=float32),
#   'logits': array([0.6584238], dtype=float32),
#   'probabilities': array([0.3410938, 0.6589063], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6470982], dtype=float32),
#   'logits': array([0.60630834], dtype=float32),
#   'probabilities': array([0.3529018 , 0.64709824], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52674204], dtype=float32),
#   'logits': array([0.10707033], dtype=float32),
#   'probabilities': array([0.47325796, 0.52674204], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34252083], dtype=float32),
#   'logits': array([-0.65208066], dtype=float32),
#   'probabilities': array([0.65747917, 0.3425208 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4785334], dtype=float32),
#   'logits': array([-0.08591932], dtype=float32),
#   'probabilities': array([0.5214666 , 0.47853336], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.176357], dtype=float32),
#   'logits': array([-1.5412271], dtype=float32),
#   'probabilities': array([0.823643  , 0.17635696], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18042314], dtype=float32),
#   'logits': array([-1.5134832], dtype=float32),
#   'probabilities': array([0.8195768 , 0.18042316], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14842732], dtype=float32),
#   'logits': array([-1.7469895], dtype=float32),
#   'probabilities': array([0.85157263, 0.14842731], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11970242], dtype=float32),
#   'logits': array([-1.995251], dtype=float32),
#   'probabilities': array([0.88029754, 0.11970244], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6123947], dtype=float32),
#   'logits': array([0.45738935], dtype=float32),
#   'probabilities': array([0.38760534, 0.6123947 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21688119], dtype=float32),
#   'logits': array([-1.2839348], dtype=float32),
#   'probabilities': array([0.78311884, 0.21688117], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43512455], dtype=float32),
#   'logits': array([-0.26097298], dtype=float32),
#   'probabilities': array([0.5648755 , 0.43512455], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5918361], dtype=float32),
#   'logits': array([0.37156093], dtype=float32),
#   'probabilities': array([0.40816388, 0.5918361 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2829707], dtype=float32),
#   'logits': array([-0.92977345], dtype=float32),
#   'probabilities': array([0.71702933, 0.28297067], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6507022], dtype=float32),
#   'logits': array([0.6221273], dtype=float32),
#   'probabilities': array([0.34929776, 0.6507022 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12031978], dtype=float32),
#   'logits': array([-1.9894055], dtype=float32),
#   'probabilities': array([0.8796803 , 0.12031978], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60664296], dtype=float32),
#   'logits': array([0.4332229], dtype=float32),
#   'probabilities': array([0.393357, 0.606643], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12334035], dtype=float32),
#   'logits': array([-1.9611713], dtype=float32),
#   'probabilities': array([0.87665963, 0.12334034], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56968105], dtype=float32),
#   'logits': array([0.28054988], dtype=float32),
#   'probabilities': array([0.43031898, 0.56968105], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31585133], dtype=float32),
#   'logits': array([-0.7729037], dtype=float32),
#   'probabilities': array([0.68414867, 0.3158513 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15088081], dtype=float32),
#   'logits': array([-1.7277093], dtype=float32),
#   'probabilities': array([0.8491192 , 0.15088083], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5736624], dtype=float32),
#   'logits': array([0.29680955], dtype=float32),
#   'probabilities': array([0.4263376, 0.5736624], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58925736], dtype=float32),
#   'logits': array([0.36089635], dtype=float32),
#   'probabilities': array([0.41074255, 0.58925736], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54318905], dtype=float32),
#   'logits': array([0.17318785], dtype=float32),
#   'probabilities': array([0.45681098, 0.5431891 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16327554], dtype=float32),
#   'logits': array([-1.6340556], dtype=float32),
#   'probabilities': array([0.83672446, 0.16327554], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33943456], dtype=float32),
#   'logits': array([-0.6658151], dtype=float32),
#   'probabilities': array([0.66056544, 0.33943453], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14940143], dtype=float32),
#   'logits': array([-1.7393034], dtype=float32),
#   'probabilities': array([0.8505986 , 0.14940146], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.70480555], dtype=float32),
#   'logits': array([0.8702878], dtype=float32),
#   'probabilities': array([0.29519442, 0.70480555], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8146569], dtype=float32),
#   'logits': array([1.4805586], dtype=float32),
#   'probabilities': array([0.18534304, 0.8146569 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6257496], dtype=float32),
#   'logits': array([0.5140252], dtype=float32),
#   'probabilities': array([0.3742504 , 0.62574965], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20434496], dtype=float32),
#   'logits': array([-1.359356], dtype=float32),
#   'probabilities': array([0.795655  , 0.20434497], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45053786], dtype=float32),
#   'logits': array([-0.19849777], dtype=float32),
#   'probabilities': array([0.54946214, 0.45053786], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37855205], dtype=float32),
#   'logits': array([-0.49569857], dtype=float32),
#   'probabilities': array([0.621448  , 0.37855208], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44939464], dtype=float32),
#   'logits': array([-0.2031169], dtype=float32),
#   'probabilities': array([0.55060536, 0.44939464], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35492665], dtype=float32),
#   'logits': array([-0.59745294], dtype=float32),
#   'probabilities': array([0.6450734 , 0.35492665], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45888427], dtype=float32),
#   'logits': array([-0.16483516], dtype=float32),
#   'probabilities': array([0.54111576, 0.4588843 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14483899], dtype=float32),
#   'logits': array([-1.7756672], dtype=float32),
#   'probabilities': array([0.855161  , 0.14483897], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5752395], dtype=float32),
#   'logits': array([0.30326092], dtype=float32),
#   'probabilities': array([0.42476052, 0.5752395 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5762501], dtype=float32),
#   'logits': array([0.30739832], dtype=float32),
#   'probabilities': array([0.4237499, 0.5762501], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2328116], dtype=float32),
#   'logits': array([-1.192503], dtype=float32),
#   'probabilities': array([0.76718843, 0.23281157], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16266185], dtype=float32),
#   'logits': array([-1.6385543], dtype=float32),
#   'probabilities': array([0.8373381 , 0.16266187], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16878697], dtype=float32),
#   'logits': array([-1.5942488], dtype=float32),
#   'probabilities': array([0.83121306, 0.16878697], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26788372], dtype=float32),
#   'logits': array([-1.0053865], dtype=float32),
#   'probabilities': array([0.73211634, 0.26788372], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38899744], dtype=float32),
#   'logits': array([-0.45152837], dtype=float32),
#   'probabilities': array([0.61100256, 0.38899747], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12630484], dtype=float32),
#   'logits': array([-1.9340333], dtype=float32),
#   'probabilities': array([0.8736952 , 0.12630484], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3240084], dtype=float32),
#   'logits': array([-0.7354113], dtype=float32),
#   'probabilities': array([0.67599165, 0.3240084 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24327692], dtype=float32),
#   'logits': array([-1.1347971], dtype=float32),
#   'probabilities': array([0.7567231, 0.2432769], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09557588], dtype=float32),
#   'logits': array([-2.2473779], dtype=float32),
#   'probabilities': array([0.90442413, 0.09557588], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12209076], dtype=float32),
#   'logits': array([-1.9727786], dtype=float32),
#   'probabilities': array([0.87790924, 0.12209075], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74950546], dtype=float32),
#   'logits': array([1.0959766], dtype=float32),
#   'probabilities': array([0.2504945, 0.7495055], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17119816], dtype=float32),
#   'logits': array([-1.5771594], dtype=float32),
#   'probabilities': array([0.8288018 , 0.17119816], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12073246], dtype=float32),
#   'logits': array([-1.9855123], dtype=float32),
#   'probabilities': array([0.8792675 , 0.12073246], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13980362], dtype=float32),
#   'logits': array([-1.8169217], dtype=float32),
#   'probabilities': array([0.86019635, 0.13980365], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4828478], dtype=float32),
#   'logits': array([-0.0686357], dtype=float32),
#   'probabilities': array([0.5171522, 0.4828478], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46685722], dtype=float32),
#   'logits': array([-0.13276583], dtype=float32),
#   'probabilities': array([0.53314275, 0.46685717], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23104987], dtype=float32),
#   'logits': array([-1.2023925], dtype=float32),
#   'probabilities': array([0.76895016, 0.2310499 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43838602], dtype=float32),
#   'logits': array([-0.24771494], dtype=float32),
#   'probabilities': array([0.561614, 0.438386], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16914333], dtype=float32),
#   'logits': array([-1.5917108], dtype=float32),
#   'probabilities': array([0.8308567 , 0.16914333], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2189921], dtype=float32),
#   'logits': array([-1.2715497], dtype=float32),
#   'probabilities': array([0.78100795, 0.2189921 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48751056], dtype=float32),
#   'logits': array([-0.04996812], dtype=float32),
#   'probabilities': array([0.51248944, 0.48751056], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4727901], dtype=float32),
#   'logits': array([-0.10894734], dtype=float32),
#   'probabilities': array([0.52720994, 0.4727901 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12941927], dtype=float32),
#   'logits': array([-1.9061031], dtype=float32),
#   'probabilities': array([0.87058073, 0.12941928], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40811223], dtype=float32),
#   'logits': array([-0.3717749], dtype=float32),
#   'probabilities': array([0.5918878 , 0.40811217], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6889033], dtype=float32),
#   'logits': array([0.7949971], dtype=float32),
#   'probabilities': array([0.3110967, 0.6889033], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5355456], dtype=float32),
#   'logits': array([0.14242268], dtype=float32),
#   'probabilities': array([0.46445438, 0.5355456 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38833416], dtype=float32),
#   'logits': array([-0.45432], dtype=float32),
#   'probabilities': array([0.61166584, 0.38833413], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5732587], dtype=float32),
#   'logits': array([0.29515922], dtype=float32),
#   'probabilities': array([0.42674127, 0.57325876], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23823516], dtype=float32),
#   'logits': array([-1.1623796], dtype=float32),
#   'probabilities': array([0.7617649 , 0.23823519], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17838162], dtype=float32),
#   'logits': array([-1.5273508], dtype=float32),
#   'probabilities': array([0.8216184 , 0.17838164], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12232867], dtype=float32),
#   'logits': array([-1.9705608], dtype=float32),
#   'probabilities': array([0.87767136, 0.12232866], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26154786], dtype=float32),
#   'logits': array([-1.037939], dtype=float32),
#   'probabilities': array([0.73845214, 0.26154786], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49171364], dtype=float32),
#   'logits': array([-0.03314841], dtype=float32),
#   'probabilities': array([0.5082863, 0.4917136], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6872146], dtype=float32),
#   'logits': array([0.7871295], dtype=float32),
#   'probabilities': array([0.31278536, 0.6872147 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22722867], dtype=float32),
#   'logits': array([-1.2240264], dtype=float32),
#   'probabilities': array([0.77277136, 0.22722866], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15802443], dtype=float32),
#   'logits': array([-1.6730015], dtype=float32),
#   'probabilities': array([0.8419756 , 0.15802442], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41822755], dtype=float32),
#   'logits': array([-0.3300537], dtype=float32),
#   'probabilities': array([0.58177245, 0.41822755], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22277635], dtype=float32),
#   'logits': array([-1.2495598], dtype=float32),
#   'probabilities': array([0.77722365, 0.22277635], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13945279], dtype=float32),
#   'logits': array([-1.8198423], dtype=float32),
#   'probabilities': array([0.8605472, 0.1394528], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.176041], dtype=float32),
#   'logits': array([-1.5434039], dtype=float32),
#   'probabilities': array([0.823959  , 0.17604099], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12260142], dtype=float32),
#   'logits': array([-1.9680223], dtype=float32),
#   'probabilities': array([0.8773985 , 0.12260146], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37830186], dtype=float32),
#   'logits': array([-0.49676228], dtype=float32),
#   'probabilities': array([0.62169814, 0.37830183], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78220415], dtype=float32),
#   'logits': array([1.2785578], dtype=float32),
#   'probabilities': array([0.21779582, 0.7822042 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
# ...
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6937373], dtype=float32),
#   'logits': array([0.81765044], dtype=float32),
#   'probabilities': array([0.3062626, 0.6937373], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6328592], dtype=float32),
#   'logits': array([0.5445025], dtype=float32),
#   'probabilities': array([0.3671408, 0.6328592], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.70374465], dtype=float32),
#   'logits': array([0.86519384], dtype=float32),
#   'probabilities': array([0.29625535, 0.70374465], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45932025], dtype=float32),
#   'logits': array([-0.16307938], dtype=float32),
#   'probabilities': array([0.5406797 , 0.45932022], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3009348], dtype=float32),
#   'logits': array([-0.84285057], dtype=float32),
#   'probabilities': array([0.6990652 , 0.30093476], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52000403], dtype=float32),
#   'logits': array([0.08005881], dtype=float32),
#   'probabilities': array([0.479996  , 0.52000403], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17164603], dtype=float32),
#   'logits': array([-1.5740062], dtype=float32),
#   'probabilities': array([0.82835394, 0.17164601], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14475134], dtype=float32),
#   'logits': array([-1.7763747], dtype=float32),
#   'probabilities': array([0.85524863, 0.14475137], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17573217], dtype=float32),
#   'logits': array([-1.5455343], dtype=float32),
#   'probabilities': array([0.8242678 , 0.17573221], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50404626], dtype=float32),
#   'logits': array([0.01618528], dtype=float32),
#   'probabilities': array([0.49595374, 0.5040462 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05750215], dtype=float32),
#   'logits': array([-2.7967107], dtype=float32),
#   'probabilities': array([0.94249785, 0.05750218], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26872867], dtype=float32),
#   'logits': array([-1.0010823], dtype=float32),
#   'probabilities': array([0.7312713 , 0.26872867], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15938494], dtype=float32),
#   'logits': array([-1.6628115], dtype=float32),
#   'probabilities': array([0.8406151 , 0.15938495], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26682928], dtype=float32),
#   'logits': array([-1.0107695], dtype=float32),
#   'probabilities': array([0.73317075, 0.2668293 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23234293], dtype=float32),
#   'logits': array([-1.1951288], dtype=float32),
#   'probabilities': array([0.7676571 , 0.23234291], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27136028], dtype=float32),
#   'logits': array([-0.9877318], dtype=float32),
#   'probabilities': array([0.7286397, 0.2713603], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7767544], dtype=float32),
#   'logits': array([1.2468517], dtype=float32),
#   'probabilities': array([0.2232456, 0.7767544], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16119799], dtype=float32),
#   'logits': array([-1.6493413], dtype=float32),
#   'probabilities': array([0.838802  , 0.16119799], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11203095], dtype=float32),
#   'logits': array([-2.0701616], dtype=float32),
#   'probabilities': array([0.887969  , 0.11203096], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58540297], dtype=float32),
#   'logits': array([0.34499335], dtype=float32),
#   'probabilities': array([0.41459706, 0.58540297], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47776136], dtype=float32),
#   'logits': array([-0.08901334], dtype=float32),
#   'probabilities': array([0.5222387 , 0.47776136], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8467704], dtype=float32),
#   'logits': array([1.709492], dtype=float32),
#   'probabilities': array([0.15322962, 0.8467704 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63088894], dtype=float32),
#   'logits': array([0.5360323], dtype=float32),
#   'probabilities': array([0.36911103, 0.63088894], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11479675], dtype=float32),
#   'logits': array([-2.042654], dtype=float32),
#   'probabilities': array([0.88520324, 0.11479675], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6514615], dtype=float32),
#   'logits': array([0.6254697], dtype=float32),
#   'probabilities': array([0.34853846, 0.6514615 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.545003], dtype=float32),
#   'logits': array([0.18050039], dtype=float32),
#   'probabilities': array([0.45499703, 0.545003  ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77726316], dtype=float32),
#   'logits': array([1.249788], dtype=float32),
#   'probabilities': array([0.22273684, 0.77726316], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22847947], dtype=float32),
#   'logits': array([-1.2169169], dtype=float32),
#   'probabilities': array([0.7715205 , 0.22847947], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16953906], dtype=float32),
#   'logits': array([-1.5888973], dtype=float32),
#   'probabilities': array([0.83046097, 0.1695391 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54222196], dtype=float32),
#   'logits': array([0.16929114], dtype=float32),
#   'probabilities': array([0.45777798, 0.54222196], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14585975], dtype=float32),
#   'logits': array([-1.76745], dtype=float32),
#   'probabilities': array([0.8541403 , 0.14585975], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78883374], dtype=float32),
#   'logits': array([1.31791], dtype=float32),
#   'probabilities': array([0.21116622, 0.78883374], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50484574], dtype=float32),
#   'logits': array([0.01938367], dtype=float32),
#   'probabilities': array([0.49515423, 0.50484574], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1605743], dtype=float32),
#   'logits': array([-1.6539612], dtype=float32),
#   'probabilities': array([0.83942574, 0.1605743 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5443146], dtype=float32),
#   'logits': array([0.17772496], dtype=float32),
#   'probabilities': array([0.45568535, 0.5443147 ], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48154938], dtype=float32),
#   'logits': array([-0.07383597], dtype=float32),
#   'probabilities': array([0.5184506, 0.4815494], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10490292], dtype=float32),
#   'logits': array([-2.1438966], dtype=float32),
#   'probabilities': array([0.8950971 , 0.10490295], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52254975], dtype=float32),
#   'logits': array([0.09026015], dtype=float32),
#   'probabilities': array([0.47745028, 0.52254975], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60994697], dtype=float32),
#   'logits': array([0.44708943], dtype=float32),
#   'probabilities': array([0.390053  , 0.60994697], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.75822884], dtype=float32),
#   'logits': array([1.1429937], dtype=float32),
#   'probabilities': array([0.24177115, 0.75822884], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8054629], dtype=float32),
#   'logits': array([1.4207942], dtype=float32),
#   'probabilities': array([0.1945371, 0.8054629], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43687633], dtype=float32),
#   'logits': array([-0.25384915], dtype=float32),
#   'probabilities': array([0.5631237 , 0.43687633], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15344656], dtype=float32),
#   'logits': array([-1.707821], dtype=float32),
#   'probabilities': array([0.84655344, 0.15344656], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.07881763], dtype=float32),
#   'logits': array([-2.4585214], dtype=float32),
#   'probabilities': array([0.92118233, 0.07881763], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09756944], dtype=float32),
#   'logits': array([-2.2245274], dtype=float32),
#   'probabilities': array([0.90243053, 0.09756944], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.250313], dtype=float32),
#   'logits': array([-1.0969436], dtype=float32),
#   'probabilities': array([0.749687, 0.250313], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34518927], dtype=float32),
#   'logits': array([-0.64025337], dtype=float32),
#   'probabilities': array([0.6548107 , 0.34518927], dtype=float32)},
#  {'all_class_ids': array([0, 1], dtype=int32),
#   'all_classes': array([b'0', b'1'], dtype=object),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26029316], dtype=float32),
#   'logits': array([-1.0444454], dtype=float32),
#   'probabilities': array([0.7397068 , 0.26029316], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpte29r9g3
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpte29r9g3', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5eef4fde48>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-f8c9922af341> in <module>()
# ----> 1 dnn_model.train(input_fn=input_func,steps=1000)
#
# /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     368
#     369       saving_listeners = _check_listeners_type(saving_listeners)
# --> 370       loss = self._train_model(input_fn, hooks, saving_listeners)
#     371       logging.info('Loss for final step: %s.', loss)
#     372       return self
#
# /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1159       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1160     else:
# -> 1161       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1162
#    1163   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1189       worker_hooks.extend(input_hooks)
#    1190       estimator_spec = self._call_model_fn(
# -> 1191           features, labels, ModeKeys.TRAIN, self.config)
#    1192       global_step_tensor = training_util.get_global_step(g)
#    1193       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1147
#    1148     logging.info('Calling model_fn.')
# -> 1149     model_fn_results = self._model_fn(features=features, **kwargs)
#    1150     logging.info('Done calling model_fn.')
#    1151
#
# /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     809           input_layer_partitioner=input_layer_partitioner,
#     810           config=config,
# --> 811           batch_norm=batch_norm)
#     812
#     813     super(DNNClassifier, self).__init__(
#
# /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm)
#     461         input_layer_partitioner=input_layer_partitioner,
#     462         batch_norm=batch_norm)
# --> 463     logits = logit_fn(features=features, mode=mode)
#     464
#     465     return _get_dnn_estimator_spec(use_tpu, head, features, labels, mode,
#
# /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/canned/dnn.py in dnn_logit_fn(features, mode)
#     106         input_layer_partitioner,
#     107         batch_norm,
# --> 108         name='dnn')
#     109     return dnn_model(features, mode)
#     110
#
# /tensorflow-1.15.0/python3.6/tensorflow_estimator/python/estimator/canned/dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, input_layer_partitioner, batch_norm, name, **kwargs)
#     184     if feature_column_lib.is_feature_column_v2(feature_columns):
#     185       self._input_layer = dense_features.DenseFeatures(
# --> 186           feature_columns=feature_columns, name='input_layer')
#     187     else:
#     188       self._input_layer = feature_column.InputLayer(
#
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/feature_column/dense_features.py in __init__(self, feature_columns, trainable, name, **kwargs)
#      84         name=name,
#      85         expected_column_type=fc.DenseColumn,
# ---> 86         **kwargs)
#      87
#      88   @property
#
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/feature_column/feature_column_v2.py in __init__(self, feature_columns, expected_column_type, trainable, name, **kwargs)
#     378             'You can wrap a categorical column with an '
#     379             'embedding_column or indicator_column. Given: {}'.format(
# --> 380                 expected_column_type, column))
#     381
#     382   def build(self, _):
#
# ValueError: Items of feature_columns must be a <class 'tensorflow.python.feature_column.feature_column_v2.DenseColumn'>. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmprnimphz4
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmprnimphz4', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5eef4d0748>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/feature_column/feature_column_v2.py:3079: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/training/adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmprnimphz4/model.ckpt.
# INFO:tensorflow:loss = 6.959112, step = 1
# INFO:tensorflow:global_step/sec: 323.774
# INFO:tensorflow:loss = 5.463621, step = 101 (0.323 sec)
# INFO:tensorflow:global_step/sec: 424.939
# INFO:tensorflow:loss = 5.7278757, step = 201 (0.232 sec)
# INFO:tensorflow:global_step/sec: 423.434
# INFO:tensorflow:loss = 4.580714, step = 301 (0.237 sec)
# INFO:tensorflow:global_step/sec: 382.89
# INFO:tensorflow:loss = 7.7599173, step = 401 (0.262 sec)
# INFO:tensorflow:global_step/sec: 363.876
# INFO:tensorflow:loss = 5.96984, step = 501 (0.277 sec)
# INFO:tensorflow:global_step/sec: 424.287
# INFO:tensorflow:loss = 4.944142, step = 601 (0.227 sec)
# INFO:tensorflow:global_step/sec: 380.383
# INFO:tensorflow:loss = 1.1172729, step = 701 (0.261 sec)
# INFO:tensorflow:global_step/sec: 390.145
# INFO:tensorflow:loss = 5.654585, step = 801 (0.257 sec)
# INFO:tensorflow:global_step/sec: 407.671
# INFO:tensorflow:loss = 3.8846657, step = 901 (0.249 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmprnimphz4/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.6715097.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-03-17T21:10:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmprnimphz4/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-03-17-21:10:31
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72440946, accuracy_baseline = 0.65748036, auc = 0.8154725, auc_precision_recall = 0.6916903, average_loss = 0.5070058, global_step = 1000, label/mean = 0.34251967, loss = 4.953057, precision = 0.58762884, prediction/mean = 0.39933163, recall = 0.6551724
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmprnimphz4/model.ckpt-1000
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.8154725,
#  'auc_precision_recall': 0.6916903,
#  'average_loss': 0.5070058,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 4.953057,
#  'precision': 0.58762884,
#  'prediction/mean': 0.39933163,
#  'recall': 0.6551724}
